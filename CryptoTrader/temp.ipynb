# %%
names = [
    'john.szlima',
    'andreia.rizzo',
    'joseluis.m.oliveira',
    'aldomota79',
    'renatoochando',
    'mbmugnol47',
    'sergio_godinho75',
    'nayparadello',
    'paulakusieluskus',
    'catarina_cmm',
    'lucia.f.machado',
    'costaaldina',
    'elviraramos4637',
    'mia__almeida',
    '_amaze_i_am_',
    'larassantos11',
    'dreamer_pink85',
    'mario.batista2018',
    'pmtoliveira',
    'jorgemartinscpv',
    'fatimapereiragoncalves9',
    'dreamer_pink85',
    'dreamer_pink85',
    'fatimapereiragoncalves9',
    'fatimapereiragoncalves9',
    'ritagabriela__',
    'fatimapereiragoncalves9',
    'fatimapereiragoncalves9',
    'dreamer_pink85',
    'fatimapereiragoncalves9',
    'fatimapereiragoncalves9',
    'fatimapereiragoncalves9',
    'fatimapereiragoncalves9',
    'dreamer_pink85',
    'fatimapereiragoncalves9',
    'dreamer_pink85',
    'dreamer_pink85',
    'sofie.silva.27',
    'ines_idk',
    'sofie.silva.27',
    'ines_idk',
    'sofie.silva.27',
    'sofie.silva.27',
    'sofie.silva.27',
    'sofie.silva.27',
    'joana_carminho0',
    'joana_carminho0',
    'joanadiniz187',
    'joana_carminho0',
    'joanadiniz187',
    'teixeirasonia1973',
    'anabela.amorim.52',
    'manuelassantoss',
    'anabela.amorim.52',
    'joaonora_bigstudwolf_lobo',
    'si.lva6127',
    'si.lva6127',
    'manuela_basilio',
    'si.lva6127',
    'si.lva6127'
]

# %%
cleaned = [n for n in set(names)]
for name in cleaned:
    print(name)
# Out:
# dreamer_pink85
# sofie.silva.27
# john.szlima
# joana_carminho0
# aldomota79
# sergio_godinho75
# paulakusieluskus
# lucia.f.machado
# elviraramos4637
# ines_idk
# catarina_cmm
# si.lva6127
# manuela_basilio
# anabela.amorim.52
# mia__almeida
# mbmugnol47
# joseluis.m.oliveira
# nayparadello
# fatimapereiragoncalves9
# jorgemartinscpv
# ritagabriela__
# _amaze_i_am_
# manuelassantoss
# renatoochando
# larassantos11
# joaonora_bigstudwolf_lobo
# teixeirasonia1973
# mario.batista2018
# pmtoliveira
# costaaldina
# andreia.rizzo
# joanadiniz187
