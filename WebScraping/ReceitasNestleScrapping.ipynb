# %% [markdown]
# # Receitas Nestlé (https://www.receitasnestle.com.br/)

# %% [markdown]
# ## Bibliotecas

# %%
# !pip3 install beautifulsoup4

from bs4 import BeautifulSoup
import requests

# %% [markdown]
# ## 1) Obter os dados da página principal

# %%
mainUrl = 'https://www.receitasnestle.com.br/nossas-receitas'
mainText = requests.get(mainUrl).text
print(mainText)
# Out:
# <!DOCTYPE html>
# <html ng-app="cookitApp"  lang="pt-br" dir="ltr" prefix="og: https://ogp.me/ns#">
# 	<head>
# ...

# %%
soup = BeautifulSoup(mainText, 'lxml')
list_a = soup.find_all('a', class_="item")

# %%
a_list = [a['href'] for a in list_a]
print(a_list)
# Out:
# ['/categorias/iogurteria-nestle', '/categorias/aveias', '/categorias/bono', '/categorias/calipso', '/categorias/creme-de-leite', '/categorias/dois-frades', '/categorias/farinha-lactea', '/categorias-fiber-mais', '/categorias/garoto', '/categorias/KitKat', '/categorias/maggi', '/categorias/moca', '/categorias/molico', '/categorias/mucilon', '/categorias/natures-heart', '/categorias/negresco', '/categorias/nescafe-dolce-gusto', '/categorias/nescau', '/categorias/nesfit', '/categorias/nesquik', '/categorias/neston', '/categorias/ninho', '/categorias/nutren', '/categorias/passatempo', '/categorias/tostines', '/categorias/almoco', '/categorias/cafe-da-manha', '/categorias/dia-a-dia', '/categorias/acompanhamentos-e-entradas', '/categorias/Jantar', '/categorias/macarrao-pasta', '/categorias/paes-tortas', '/categorias/para-criancas', '/categorias/Pizzas', '/categorias/rapidas', '/categorias/saudaveis', '/categorias/sopas', '/categorias/sobremesas', '/categorias/saladas', '/categorias/lanches
# ...

# %%
def GetRecipies(url):
    urlText = requests.get(url).text
